# %% [markdown]
# <a href="https://colab.research.google.com/github/srujayreddyv/CSUS-CSC219-MachineLeaning/blob/main/labs/CSC219Lab04_ModelPerformanceVisualization_Srujay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #CSC 219 Machine Learning (Fall 2023)

# %% [markdown]
# #Lab4: Model Performance Evaluation

# %% [markdown]
# ### Helpful Functions for Tensorflow

# %% [markdown]
# The following functions will be used with TensorFlow to help preprocess the data.  They allow you to build the feature vector for a neural network.
#
# * Predictors/Inputs
#     * Fill any missing inputs with the median for that column.  Use **missing_median**.
#     * Encode textual/categorical values with **encode_text_dummy**.
#     * Encode numeric values with **encode_numeric_zscore**.
# * Output
#     * Discard rows with missing outputs.
#     * Encode textual/categorical values with **encode_text_index**.
#     * Do not encode output numeric values.
# * Produce final feature vectors (x) and expected output (y) with **to_xy**.

# %%
from collections.abc import Sequence
from sklearn import preprocessing
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import shutil
import os


# Encode text values to dummy variables(i.e. [1,0,0],[0,1,0],[0,0,1] for red,green,blue)
def encode_text_dummy(df, name):
    dummies = pd.get_dummies(df[name])
    for x in dummies.columns:
        dummy_name = "{}-{}".format(name, x)
        df[dummy_name] = dummies[x]
    df.drop(name, axis=1, inplace=True)



# Encode text values to indexes(i.e. [1],[2],[3] for red,green,blue).
def encode_text_index(df, name):
    le = preprocessing.LabelEncoder()
    df[name] = le.fit_transform(df[name])
    return le.classes_


# Encode a numeric column as zscores
def encode_numeric_zscore(df, name, mean=None, sd=None):
    if mean is None:
        mean = df[name].mean()

    if sd is None:
        sd = df[name].std()

    df[name] = (df[name] - mean) / sd


# Convert all missing values in the specified column to the median
def missing_median(df, name):
    med = df[name].median()
    df[name] = df[name].fillna(med)


# Convert all missing values in the specified column to the default
def missing_default(df, name, default_value):
    df[name] = df[name].fillna(default_value)


# Convert a Pandas dataframe to the x,y inputs that TensorFlow needs
def to_xy(df, target):
    result = []
    for x in df.columns:
        if x != target:
            result.append(x)
    # find out the type of the target column.
    target_type = df[target].dtypes
    target_type = target_type[0] if isinstance(target_type, Sequence) else target_type
    # Encode to int for classification, float otherwise. TensorFlow likes 32 bits.
    if target_type in (np.int64, np.int32):
        # Classification
        dummies = pd.get_dummies(df[target])
        return df[result].values.astype(np.float32), dummies.values.astype(np.float32)
    else:
        # Regression
        return df[result].values.astype(np.float32), df[target].values.astype(np.float32)

# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)


# Regression chart.
def chart_regression(pred,y,sort=True):
    t = pd.DataFrame({'pred' : pred, 'y' : y.flatten()})
    if sort:
        t.sort_values(by=['y'],inplace=True)
    a = plt.plot(t['y'].tolist(),label='expected')
    b = plt.plot(t['pred'].tolist(),label='prediction')
    plt.ylabel('output')
    plt.legend()
    plt.show()

# Remove all rows where the specified column is +/- sd standard deviations
def remove_outliers(df, name, sd):
    drop_rows = df.index[(np.abs(df[name] - df[name].mean()) >= (sd * df[name].std()))]
    df.drop(drop_rows, axis=0, inplace=True)


# Encode a column to a range between normalized_low and normalized_high.
def encode_numeric_range(df, name, normalized_low=-1, normalized_high=1,
                         data_low=None, data_high=None):
    if data_low is None:
        data_low = min(df[name])
        data_high = max(df[name])

    df[name] = ((df[name] - data_low) / (data_high - data_low)) \
               * (normalized_high - normalized_low) + normalized_low

# %% [markdown]
# ### 4.1  Metrics

# %% [markdown]
# For any type of classification neural network:
#
# * **Accuracy**
# * **Precision**
# * **Recall**
# * **F1 Score**
# * **Log Loss**
# * **Confusion Matrix**
# * **ROC Curve**
#
# For regression neural networks:
# * **RMSE**
# * **R2 Score**
# * **Lift Chart**
#
# Check Sklearn API here http://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics
#
# The code used to produce Confusion matrix and ROC curve is shown here:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Plot a confusion matrix.
# cm is the confusion matrix, names are the names of the classes.
def plot_confusion_matrix(cm, names, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(names))
    plt.xticks(tick_marks, names, rotation=45)
    plt.yticks(tick_marks, names)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')


# Plot an ROC. pred - the predictions, y - the expected output.
def plot_roc(pred,y):
    fpr, tpr, thresholds = roc_curve(y, pred)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC)')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ## 4.2 Visualizing binary classification models

# %% [markdown]
# Binary classification is used to create a model that classifies between only two classes. These two classes are often called "positive" and "negative".

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

# Set the desired TensorFlow output level for this example
# tf.logging.set_verbosity(tf.logging.ERROR)

path = "/content/drive/MyDrive/Colab Notebooks/CSC219-MachineLearning/labs/data"

filename = os.path.join(path,"wcbreast_wdbc.csv")
df = pd.read_csv(filename,na_values=['NA','?'])
df
# Out:
#            id diagnosis  mean_radius  mean_texture  mean_perimeter  mean_area  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      mean_smoothness  mean_compactness  mean_concavity  mean_concave_points  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  worst_radius  worst_texture  worst_perimeter  worst_area  \
# 0    ...        25.380          17.33           184.60      2019.0
# 1    ...        24.990          23.41           158.80      1956.0
# 2    ...        23.570          25.53           152.50      1709.0
# 3    ...        14.910          26.50            98.87       567.7
# 4    ...        22.540          16.67           152.20      1575.0
# ..   ...           ...            ...              ...         ...
# 564  ...        25.450          26.40           166.10      2027.0
# 565  ...        23.690          38.25           155.00      1731.0
# 566  ...        18.980          34.12           126.70      1124.0
# 567  ...        25.740          39.42           184.60      1821.0
# 568  ...         9.456          30.37            59.16       268.6
#
#      worst_smoothness  worst_compactness  worst_concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst_concave_points  worst_symmetry  worst_fractal_dimension
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %%
# Encode feature vector
df.drop('id',axis=1,inplace=True)

diagnosis = encode_text_index(df,'diagnosis')

# Create x & y for training and testing
x, y = to_xy(df,'diagnosis')

# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %% [markdown]
# ### Important!! Avoid local optimum: Jump out of local optimum by using a loop to train a model multiple times!!

# %%
# Define ModelCheckpoint outside the loop
checkpointer = ModelCheckpoint(filepath="/content/drive/MyDrive/Colab Notebooks/CSC219-MachineLearning/Labs/best_weights.hdf5", verbose=0, save_best_only=True) # save best model

for i in range(5):
    print(i)

    # Build network
    model = Sequential()
    model.add(Dense(20, input_dim=x.shape[1], activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(y.shape[1], activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam')

    monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=1, mode='auto')

    model.fit(x_train,y_train,validation_data=(x_test,y_test),callbacks=[monitor,checkpointer],verbose=2,epochs=100)


print('Training finished...Loading the best model')
print()
model.load_weights('/content/drive/MyDrive/Colab Notebooks/CSC219-MachineLearning/Labs/best_weights.hdf5') # load weights from best model

# Measure accuracy
pred = model.predict(x_test)
pred = np.argmax(pred,axis=1)

y_true = np.argmax(y_test,axis=1)

score = metrics.accuracy_score(y_true, pred)
print("Final accuracy: {}".format(score))
# Out:
# 0
# Epoch 1/100
# 14/14 - 1s - loss: 1.6742 - val_loss: 0.5326 - 797ms/epoch - 57ms/step
# Epoch 2/100
# 14/14 - 0s - loss: 0.8427 - val_loss: 0.5702 - 42ms/epoch - 3ms/step
# Epoch 3/100
# 14/14 - 0s - loss: 0.6025 - val_loss: 0.5767 - 60ms/epoch - 4ms/step
# Epoch 4/100
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 14/14 - 0s - loss: 0.5725 - val_loss: 0.4467 - 92ms/epoch - 7ms/step
# Epoch 5/100
# 14/14 - 0s - loss: 0.4907 - val_loss: 0.4787 - 43ms/epoch - 3ms/step
# Epoch 6/100
# 14/14 - 0s - loss: 0.4849 - val_loss: 0.3947 - 77ms/epoch - 5ms/step
# Epoch 7/100
# 14/14 - 0s - loss: 0.4468 - val_loss: 0.3421 - 70ms/epoch - 5ms/step
# Epoch 8/100
# 14/14 - 0s - loss: 0.4261 - val_loss: 0.3669 - 39ms/epoch - 3ms/step
# Epoch 9/100
# 14/14 - 0s - loss: 0.3949 - val_loss: 0.3302 - 82ms/epoch - 6ms/step
# Epoch 10/100
# 14/14 - 0s - loss: 0.4559 - val_loss: 0.3220 - 67ms/epoch - 5ms/step
# Epoch 11/100
# 14/14 - 0s - loss: 0.4660 - val_loss: 0.3040 - 90ms/epoch - 6ms/step
# Epoch 12/100
# 14/14 - 0s - loss: 0.4577 - val_loss: 0.3050 - 66ms/epoch - 5ms/step
# Epoch 13/100
# 14/14 - 0s - loss: 0.4398 - val_loss: 0.2615 - 75ms/epoch - 5ms/step
# Epoch 14/100
# 14/14 - 0s - loss: 0.3874 - val_loss: 0.2354 - 85ms/epoch - 6ms/step
# Epoch 15/100
# 14/14 - 0s - loss: 0.3875 - val_loss: 0.2343 - 86ms/epoch - 6ms/step
# Epoch 16/100
# 14/14 - 0s - loss: 0.3756 - val_loss: 0.2189 - 85ms/epoch - 6ms/step
# Epoch 17/100
# 14/14 - 0s - loss: 0.3977 - val_loss: 0.2026 - 90ms/epoch - 6ms/step
# Epoch 18/100
# 14/14 - 0s - loss: 0.3404 - val_loss: 0.2484 - 51ms/epoch - 4ms/step
# Epoch 19/100
# 14/14 - 0s - loss: 0.3328 - val_loss: 0.2637 - 66ms/epoch - 5ms/step
# Epoch 20/100
# 14/14 - 0s - loss: 0.3713 - val_loss: 0.2181 - 61ms/epoch - 4ms/step
# Epoch 21/100
# 14/14 - 0s - loss: 0.3341 - val_loss: 0.2157 - 62ms/epoch - 4ms/step
# Epoch 22/100
# 14/14 - 0s - loss: 0.3611 - val_loss: 0.3208 - 267ms/epoch - 19ms/step
# Epoch 22: early stopping
# 1
# Epoch 1/100
# 14/14 - 1s - loss: 13.1576 - val_loss: 3.7519 - 735ms/epoch - 52ms/step
# Epoch 2/100
# 14/14 - 0s - loss: 3.7869 - val_loss: 2.7246 - 67ms/epoch - 5ms/step
# Epoch 3/100
# 14/14 - 0s - loss: 2.3881 - val_loss: 1.7263 - 64ms/epoch - 5ms/step
# Epoch 4/100
# 14/14 - 0s - loss: 1.2042 - val_loss: 0.4859 - 68ms/epoch - 5ms/step
# Epoch 5/100
# 14/14 - 0s - loss: 0.6323 - val_loss: 0.3624 - 53ms/epoch - 4ms/step
# Epoch 6/100
# 14/14 - 0s - loss: 0.5651 - val_loss: 0.3410 - 59ms/epoch - 4ms/step
# Epoch 7/100
# 14/14 - 0s - loss: 0.5428 - val_loss: 0.3592 - 57ms/epoch - 4ms/step
# Epoch 8/100
# 14/14 - 0s - loss: 0.5228 - val_loss: 0.3584 - 50ms/epoch - 4ms/step
# Epoch 9/100
# 14/14 - 0s - loss: 0.5183 - val_loss: 0.3539 - 55ms/epoch - 4ms/step
# Epoch 10/100
# 14/14 - 0s - loss: 0.5020 - val_loss: 0.3596 - 49ms/epoch - 4ms/step
# Epoch 11/100
# 14/14 - 0s - loss: 0.4954 - val_loss: 0.3181 - 53ms/epoch - 4ms/step
# Epoch 12/100
# 14/14 - 0s - loss: 0.4731 - val_loss: 0.3018 - 67ms/epoch - 5ms/step
# Epoch 13/100
# 14/14 - 0s - loss: 0.4997 - val_loss: 0.3001 - 58ms/epoch - 4ms/step
# Epoch 14/100
# 14/14 - 0s - loss: 0.4415 - val_loss: 0.4275 - 41ms/epoch - 3ms/step
# Epoch 15/100
# 14/14 - 0s - loss: 0.5117 - val_loss: 0.2970 - 42ms/epoch - 3ms/step
# Epoch 16/100
# 14/14 - 0s - loss: 0.4293 - val_loss: 0.2728 - 40ms/epoch - 3ms/step
# Epoch 17/100
# 14/14 - 0s - loss: 0.4186 - val_loss: 0.2589 - 47ms/epoch - 3ms/step
# Epoch 18/100
# 14/14 - 0s - loss: 0.4230 - val_loss: 0.2710 - 56ms/epoch - 4ms/step
# Epoch 19/100
# 14/14 - 0s - loss: 0.4629 - val_loss: 0.2987 - 56ms/epoch - 4ms/step
# Epoch 20/100
# 14/14 - 0s - loss: 0.5104 - val_loss: 0.2504 - 38ms/epoch - 3ms/step
# Epoch 21/100
# 14/14 - 0s - loss: 0.4431 - val_loss: 0.2418 - 58ms/epoch - 4ms/step
# Epoch 22/100
# 14/14 - 0s - loss: 0.3948 - val_loss: 0.2413 - 53ms/epoch - 4ms/step
# Epoch 23/100
# 14/14 - 0s - loss: 0.3819 - val_loss: 0.2427 - 41ms/epoch - 3ms/step
# Epoch 24/100
# 14/14 - 0s - loss: 0.3651 - val_loss: 0.2211 - 40ms/epoch - 3ms/step
# Epoch 25/100
# 14/14 - 0s - loss: 0.3591 - val_loss: 0.2218 - 56ms/epoch - 4ms/step
# Epoch 26/100
# 14/14 - 0s - loss: 0.3565 - val_loss: 0.2166 - 43ms/epoch - 3ms/step
# Epoch 27/100
# 14/14 - 0s - loss: 0.3531 - val_loss: 0.2337 - 40ms/epoch - 3ms/step
# Epoch 28/100
# 14/14 - 0s - loss: 0.3574 - val_loss: 0.2227 - 59ms/epoch - 4ms/step
# Epoch 29/100
# 14/14 - 0s - loss: 0.3476 - val_loss: 0.2318 - 54ms/epoch - 4ms/step
# Epoch 30/100
# 14/14 - 0s - loss: 0.3848 - val_loss: 0.2140 - 57ms/epoch - 4ms/step
# Epoch 31/100
# 14/14 - 0s - loss: 0.3421 - val_loss: 0.2174 - 44ms/epoch - 3ms/step
# Epoch 32/100
# 14/14 - 0s - loss: 0.3299 - val_loss: 0.2194 - 55ms/epoch - 4ms/step
# Epoch 33/100
# 14/14 - 0s - loss: 0.3624 - val_loss: 0.2003 - 77ms/epoch - 6ms/step
# Epoch 34/100
# 14/14 - 0s - loss: 0.3582 - val_loss: 0.1997 - 62ms/epoch - 4ms/step
# Epoch 35/100
# 14/14 - 0s - loss: 0.3689 - val_loss: 0.2036 - 64ms/epoch - 5ms/step
# Epoch 36/100
# 14/14 - 0s - loss: 0.4363 - val_loss: 0.1996 - 75ms/epoch - 5ms/step
# Epoch 37/100
# 14/14 - 0s - loss: 0.3172 - val_loss: 0.1960 - 86ms/epoch - 6ms/step
# Epoch 38/100
# 14/14 - 0s - loss: 0.3156 - val_loss: 0.2078 - 53ms/epoch - 4ms/step
# Epoch 39/100
# 14/14 - 0s - loss: 0.3135 - val_loss: 0.1942 - 70ms/epoch - 5ms/step
# Epoch 40/100
# 14/14 - 0s - loss: 0.3127 - val_loss: 0.1896 - 76ms/epoch - 5ms/step
# Epoch 41/100
# 14/14 - 0s - loss: 0.3163 - val_loss: 0.1908 - 54ms/epoch - 4ms/step
# Epoch 42/100
# 14/14 - 0s - loss: 0.3541 - val_loss: 0.1897 - 37ms/epoch - 3ms/step
# Epoch 43/100
# 14/14 - 0s - loss: 0.3803 - val_loss: 0.1992 - 50ms/epoch - 4ms/step
# Epoch 44/100
# 14/14 - 0s - loss: 0.3411 - val_loss: 0.1953 - 43ms/epoch - 3ms/step
# Epoch 45/100
# 14/14 - 0s - loss: 0.2950 - val_loss: 0.1774 - 83ms/epoch - 6ms/step
# Epoch 46/100
# 14/14 - 0s - loss: 0.3315 - val_loss: 0.1848 - 40ms/epoch - 3ms/step
# Epoch 47/100
# 14/14 - 0s - loss: 0.3258 - val_loss: 0.2852 - 38ms/epoch - 3ms/step
# Epoch 48/100
# 14/14 - 0s - loss: 0.3342 - val_loss: 0.2091 - 46ms/epoch - 3ms/step
# Epoch 49/100
# 14/14 - 0s - loss: 0.3217 - val_loss: 0.2068 - 53ms/epoch - 4ms/step
# Epoch 50/100
# 14/14 - 0s - loss: 0.3012 - val_loss: 0.1824 - 54ms/epoch - 4ms/step
# Epoch 50: early stopping
# 2
# Epoch 1/100
# 14/14 - 1s - loss: 10.1462 - val_loss: 2.6258 - 570ms/epoch - 41ms/step
# Epoch 2/100
# 14/14 - 0s - loss: 3.1060 - val_loss: 1.9030 - 53ms/epoch - 4ms/step
# Epoch 3/100
# 14/14 - 0s - loss: 1.9265 - val_loss: 1.2137 - 40ms/epoch - 3ms/step
# Epoch 4/100
# 14/14 - 0s - loss: 1.5973 - val_loss: 0.9372 - 42ms/epoch - 3ms/step
# Epoch 5/100
# 14/14 - 0s - loss: 1.3158 - val_loss: 0.6546 - 40ms/epoch - 3ms/step
# Epoch 6/100
# 14/14 - 0s - loss: 1.0258 - val_loss: 0.7250 - 39ms/epoch - 3ms/step
# Epoch 7/100
# 14/14 - 0s - loss: 0.6761 - val_loss: 0.5239 - 56ms/epoch - 4ms/step
# Epoch 8/100
# 14/14 - 0s - loss: 0.5639 - val_loss: 0.2976 - 55ms/epoch - 4ms/step
# Epoch 9/100
# 14/14 - 0s - loss: 0.4368 - val_loss: 0.2781 - 55ms/epoch - 4ms/step
# Epoch 10/100
# 14/14 - 0s - loss: 0.6263 - val_loss: 0.3328 - 46ms/epoch - 3ms/step
# Epoch 11/100
# 14/14 - 0s - loss: 0.4803 - val_loss: 0.2782 - 56ms/epoch - 4ms/step
# Epoch 12/100
# 14/14 - 0s - loss: 0.3726 - val_loss: 0.2379 - 58ms/epoch - 4ms/step
# Epoch 13/100
# 14/14 - 0s - loss: 0.5203 - val_loss: 0.5221 - 42ms/epoch - 3ms/step
# Epoch 14/100
# 14/14 - 0s - loss: 0.4428 - val_loss: 0.2116 - 42ms/epoch - 3ms/step
# Epoch 15/100
# 14/14 - 0s - loss: 0.4151 - val_loss: 0.2049 - 54ms/epoch - 4ms/step
# Epoch 16/100
# 14/14 - 0s - loss: 0.4041 - val_loss: 0.2546 - 41ms/epoch - 3ms/step
# Epoch 17/100
# 14/14 - 0s - loss: 0.3548 - val_loss: 0.3322 - 41ms/epoch - 3ms/step
# Epoch 18/100
# 14/14 - 0s - loss: 0.4512 - val_loss: 0.1983 - 39ms/epoch - 3ms/step
# Epoch 19/100
# 14/14 - 0s - loss: 0.4897 - val_loss: 0.4150 - 55ms/epoch - 4ms/step
# Epoch 20/100
# 14/14 - 0s - loss: 0.6349 - val_loss: 0.1909 - 53ms/epoch - 4ms/step
# Epoch 21/100
# 14/14 - 0s - loss: 0.4764 - val_loss: 0.2062 - 53ms/epoch - 4ms/step
# Epoch 22/100
# 14/14 - 0s - loss: 0.4362 - val_loss: 0.3869 - 40ms/epoch - 3ms/step
# Epoch 23/100
# 14/14 - 0s - loss: 0.3466 - val_loss: 0.2553 - 38ms/epoch - 3ms/step
# Epoch 24/100
# 14/14 - 0s - loss: 0.3072 - val_loss: 0.1565 - 63ms/epoch - 4ms/step
# Epoch 25/100
# 14/14 - 0s - loss: 0.3175 - val_loss: 0.1527 - 64ms/epoch - 5ms/step
# Epoch 26/100
# 14/14 - 0s - loss: 0.2872 - val_loss: 0.1575 - 41ms/epoch - 3ms/step
# Epoch 27/100
# 14/14 - 0s - loss: 0.2807 - val_loss: 0.1494 - 81ms/epoch - 6ms/step
# Epoch 28/100
# 14/14 - 0s - loss: 0.2737 - val_loss: 0.1744 - 54ms/epoch - 4ms/step
# Epoch 29/100
# 14/14 - 0s - loss: 0.3370 - val_loss: 0.1489 - 74ms/epoch - 5ms/step
# Epoch 30/100
# 14/14 - 0s - loss: 0.2473 - val_loss: 0.1491 - 41ms/epoch - 3ms/step
# Epoch 31/100
# 14/14 - 0s - loss: 0.3001 - val_loss: 0.1724 - 54ms/epoch - 4ms/step
# Epoch 32/100
# 14/14 - 0s - loss: 0.2794 - val_loss: 0.1461 - 66ms/epoch - 5ms/step
# Epoch 33/100
# 14/14 - 0s - loss: 0.2794 - val_loss: 0.1414 - 60ms/epoch - 4ms/step
# Epoch 34/100
# 14/14 - 0s - loss: 0.2653 - val_loss: 0.3508 - 44ms/epoch - 3ms/step
# Epoch 35/100
# 14/14 - 0s - loss: 0.4003 - val_loss: 0.1435 - 41ms/epoch - 3ms/step
# Epoch 36/100
# 14/14 - 0s - loss: 0.2312 - val_loss: 0.2145 - 44ms/epoch - 3ms/step
# Epoch 37/100
# 14/14 - 0s - loss: 0.3316 - val_loss: 0.1269 - 66ms/epoch - 5ms/step
# Epoch 38/100
# 14/14 - 0s - loss: 0.3113 - val_loss: 0.2045 - 54ms/epoch - 4ms/step
# Epoch 39/100
# 14/14 - 0s - loss: 0.2642 - val_loss: 0.2786 - 58ms/epoch - 4ms/step
# Epoch 40/100
# 14/14 - 0s - loss: 0.3061 - val_loss: 0.1496 - 56ms/epoch - 4ms/step
# Epoch 41/100
# 14/14 - 0s - loss: 0.2686 - val_loss: 0.2981 - 59ms/epoch - 4ms/step
# Epoch 42/100
# 14/14 - 0s - loss: 0.3168 - val_loss: 0.3999 - 41ms/epoch - 3ms/step
# Epoch 42: early stopping
# 3
# Epoch 1/100
# 14/14 - 1s - loss: 36.8433 - val_loss: 4.9502 - 606ms/epoch - 43ms/step
# Epoch 2/100
# 14/14 - 0s - loss: 5.6109 - val_loss: 0.7613 - 37ms/epoch - 3ms/step
# Epoch 3/100
# 14/14 - 0s - loss: 2.1495 - val_loss: 0.6948 - 53ms/epoch - 4ms/step
# Epoch 4/100
# 14/14 - 0s - loss: 1.1952 - val_loss: 0.6361 - 54ms/epoch - 4ms/step
# Epoch 5/100
# 14/14 - 0s - loss: 0.9332 - val_loss: 0.6558 - 55ms/epoch - 4ms/step
# Epoch 6/100
# 14/14 - 0s - loss: 0.9831 - val_loss: 0.8363 - 46ms/epoch - 3ms/step
# Epoch 7/100
# 14/14 - 0s - loss: 0.9973 - val_loss: 0.5764 - 36ms/epoch - 3ms/step
# Epoch 8/100
# 14/14 - 0s - loss: 0.8753 - val_loss: 0.5677 - 42ms/epoch - 3ms/step
# Epoch 9/100
# 14/14 - 0s - loss: 0.8250 - val_loss: 0.5183 - 40ms/epoch - 3ms/step
# Epoch 10/100
# 14/14 - 0s - loss: 0.7810 - val_loss: 0.5468 - 41ms/epoch - 3ms/step
# Epoch 11/100
# 14/14 - 0s - loss: 0.7838 - val_loss: 0.4774 - 40ms/epoch - 3ms/step
# Epoch 12/100
# 14/14 - 0s - loss: 0.7262 - val_loss: 0.5063 - 36ms/epoch - 3ms/step
# Epoch 13/100
# 14/14 - 0s - loss: 0.7681 - val_loss: 0.4879 - 54ms/epoch - 4ms/step
# Epoch 14/100
# 14/14 - 0s - loss: 0.7317 - val_loss: 0.4588 - 43ms/epoch - 3ms/step
# Epoch 15/100
# 14/14 - 0s - loss: 0.6919 - val_loss: 0.4297 - 53ms/epoch - 4ms/step
# Epoch 16/100
# 14/14 - 0s - loss: 0.6939 - val_loss: 0.5579 - 53ms/epoch - 4ms/step
# Epoch 17/100
# 14/14 - 0s - loss: 0.7348 - val_loss: 0.4953 - 42ms/epoch - 3ms/step
# Epoch 18/100
# 14/14 - 0s - loss: 0.7095 - val_loss: 0.4279 - 37ms/epoch - 3ms/step
# Epoch 19/100
# 14/14 - 0s - loss: 0.6278 - val_loss: 0.4322 - 54ms/epoch - 4ms/step
# Epoch 20/100
# 14/14 - 0s - loss: 0.6528 - val_loss: 0.4064 - 58ms/epoch - 4ms/step
# Epoch 21/100
# 14/14 - 0s - loss: 0.6562 - val_loss: 0.3955 - 41ms/epoch - 3ms/step
# Epoch 22/100
# 14/14 - 0s - loss: 0.6536 - val_loss: 0.4119 - 42ms/epoch - 3ms/step
# Epoch 23/100
# 14/14 - 0s - loss: 0.5923 - val_loss: 0.3648 - 57ms/epoch - 4ms/step
# Epoch 24/100
# 14/14 - 0s - loss: 0.6072 - val_loss: 0.3451 - 57ms/epoch - 4ms/step
# Epoch 25/100
# 14/14 - 0s - loss: 0.5424 - val_loss: 0.3620 - 48ms/epoch - 3ms/step
# Epoch 26/100
# 14/14 - 0s - loss: 0.5553 - val_loss: 0.3993 - 40ms/epoch - 3ms/step
# Epoch 27/100
# 14/14 - 0s - loss: 0.5565 - val_loss: 0.3223 - 38ms/epoch - 3ms/step
# Epoch 28/100
# 14/14 - 0s - loss: 0.5344 - val_loss: 0.3150 - 56ms/epoch - 4ms/step
# Epoch 29/100
# 14/14 - 0s - loss: 0.5126 - val_loss: 0.3064 - 37ms/epoch - 3ms/step
# Epoch 30/100
# 14/14 - 0s - loss: 0.5048 - val_loss: 0.3532 - 55ms/epoch - 4ms/step
# Epoch 31/100
# 14/14 - 0s - loss: 0.4789 - val_loss: 0.2909 - 42ms/epoch - 3ms/step
# Epoch 32/100
# 14/14 - 0s - loss: 0.5016 - val_loss: 0.2982 - 54ms/epoch - 4ms/step
# Epoch 33/100
# 14/14 - 0s - loss: 0.4894 - val_loss: 0.3087 - 55ms/epoch - 4ms/step
# Epoch 34/100
# 14/14 - 0s - loss: 0.4479 - val_loss: 0.3084 - 55ms/epoch - 4ms/step
# Epoch 35/100
# 14/14 - 0s - loss: 0.5030 - val_loss: 0.3057 - 40ms/epoch - 3ms/step
# Epoch 36/100
# 14/14 - 0s - loss: 0.4861 - val_loss: 0.2703 - 45ms/epoch - 3ms/step
# Epoch 37/100
# 14/14 - 0s - loss: 0.4467 - val_loss: 0.2972 - 47ms/epoch - 3ms/step
# Epoch 38/100
# 14/14 - 0s - loss: 0.4748 - val_loss: 0.2662 - 55ms/epoch - 4ms/step
# Epoch 39/100
# 14/14 - 0s - loss: 0.4491 - val_loss: 0.3129 - 42ms/epoch - 3ms/step
# Epoch 40/100
# 14/14 - 0s - loss: 0.4492 - val_loss: 0.3035 - 57ms/epoch - 4ms/step
# Epoch 41/100
# 14/14 - 0s - loss: 0.4633 - val_loss: 0.3035 - 56ms/epoch - 4ms/step
# Epoch 42/100
# 14/14 - 0s - loss: 0.4937 - val_loss: 0.3489 - 57ms/epoch - 4ms/step
# Epoch 43/100
# 14/14 - 0s - loss: 0.5536 - val_loss: 0.4734 - 56ms/epoch - 4ms/step
# Epoch 43: early stopping
# 4
# Epoch 1/100
# 14/14 - 1s - loss: 17.4299 - val_loss: 4.7121 - 577ms/epoch - 41ms/step
# Epoch 2/100
# 14/14 - 0s - loss: 4.0007 - val_loss: 1.0378 - 54ms/epoch - 4ms/step
# Epoch 3/100
# 14/14 - 0s - loss: 2.5375 - val_loss: 1.5629 - 57ms/epoch - 4ms/step
# Epoch 4/100
# 14/14 - 0s - loss: 1.6254 - val_loss: 0.5944 - 45ms/epoch - 3ms/step
# Epoch 5/100
# 14/14 - 0s - loss: 1.3405 - val_loss: 0.6878 - 57ms/epoch - 4ms/step
# Epoch 6/100
# 14/14 - 0s - loss: 1.0803 - val_loss: 0.3871 - 57ms/epoch - 4ms/step
# Epoch 7/100
# 14/14 - 0s - loss: 0.9347 - val_loss: 0.3276 - 43ms/epoch - 3ms/step
# Epoch 8/100
# 14/14 - 0s - loss: 0.7759 - val_loss: 0.2661 - 53ms/epoch - 4ms/step
# Epoch 9/100
# 14/14 - 0s - loss: 0.6178 - val_loss: 0.2279 - 53ms/epoch - 4ms/step
# Epoch 10/100
# 14/14 - 0s - loss: 0.5655 - val_loss: 0.2041 - 52ms/epoch - 4ms/step
# Epoch 11/100
# 14/14 - 0s - loss: 0.5029 - val_loss: 0.2070 - 53ms/epoch - 4ms/step
# Epoch 12/100
# 14/14 - 0s - loss: 0.4612 - val_loss: 0.3117 - 36ms/epoch - 3ms/step
# Epoch 13/100
# 14/14 - 0s - loss: 0.4597 - val_loss: 0.1918 - 64ms/epoch - 5ms/step
# Epoch 14/100
# 14/14 - 0s - loss: 0.3927 - val_loss: 0.1510 - 38ms/epoch - 3ms/step
# Epoch 15/100
# 14/14 - 0s - loss: 0.3615 - val_loss: 0.1451 - 42ms/epoch - 3ms/step
# Epoch 16/100
# 14/14 - 0s - loss: 0.3346 - val_loss: 0.1649 - 54ms/epoch - 4ms/step
# Epoch 17/100
# 14/14 - 0s - loss: 0.3422 - val_loss: 0.2091 - 40ms/epoch - 3ms/step
# Epoch 18/100
# 14/14 - 0s - loss: 0.3208 - val_loss: 0.1377 - 57ms/epoch - 4ms/step
# Epoch 19/100
# 14/14 - 0s - loss: 0.3052 - val_loss: 0.1462 - 42ms/epoch - 3ms/step
# Epoch 20/100
# 14/14 - 0s - loss: 0.3004 - val_loss: 0.1368 - 37ms/epoch - 3ms/step
# Epoch 21/100
# 14/14 - 0s - loss: 0.2523 - val_loss: 0.1394 - 52ms/epoch - 4ms/step
# Epoch 22/100
# 14/14 - 0s - loss: 0.2626 - val_loss: 0.1698 - 43ms/epoch - 3ms/step
# Epoch 23/100
# 14/14 - 0s - loss: 0.2595 - val_loss: 0.2446 - 40ms/epoch - 3ms/step
# Epoch 23: early stopping
# Training finished...Loading the best model
#
# 5/5 [==============================] - 0s 1ms/step
# Final accuracy: 0.958041958041958

# %% [markdown]
# ###Confusion Matrix

# %% [markdown]
# The confusion matrix is a common visualization for both binary and multi-class classification problems. The following code generates a confusion matrix:

# %%
import numpy as np

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# Compute confusion matrix
cm = confusion_matrix(y_true, pred)
print(cm)


print('Plotting confusion matrix')

plt.figure()
plot_confusion_matrix(cm, diagnosis)
plt.show()

print(classification_report(y_true, pred))
# Out:
# [[87  2]
#  [ 4 50]]
# Plotting confusion matrix
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        89
#            1       0.96      0.93      0.94        54
#
#     accuracy                           0.96       143
#    macro avg       0.96      0.95      0.96       143
# weighted avg       0.96      0.96      0.96       143

# %% [markdown]
# ### ROC Curves

# %% [markdown]
# **An ROC curve measures how good a model is regardless of the cutoff.**
#
# The following code shows an ROC chart for the breast cancer neural network.  The area under the curve (AUC) is also an important measure.  The larger the AUC, the better.

# %%
pred = model.predict(x_test)
pred = pred[:,1] # Only positive class (M)
plot_roc(pred,y_true)
# Out:
# 5/5 [==============================] - 0s 1ms/step

# %% [markdown]
# ## 4.3 Visualizing multi-class classification models

# %% [markdown]
# We've already seen multi-class classification, with the iris dataset. Confusion matrixes work just fine with 3 classes. The following code generates a confusion matrix for iris.

# %%
import pandas as pd
import io
import requests
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

path = "/content/drive/MyDrive/Colab Notebooks/CSC219-MachineLearning/labs/data"

filename = os.path.join(path,"iris.csv")
df = pd.read_csv(filename,na_values=['NA','?'])

species = encode_text_index(df,"species")
x,y = to_xy(df,"species")

# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

model = Sequential()
model.add(Dense(20, input_dim=x.shape[1], activation='relu'))
model.add(Dense(10))
model.add(Dense(y.shape[1],activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=0, mode='auto')
checkpointer = ModelCheckpoint(filepath="/content/drive/MyDrive/Colab Notebooks/CSC219-MachineLearning/labs/data/best_weights.hdf5", verbose=0, save_best_only=True) # save best model

model.fit(x_train,y_train,validation_data=(x_test,y_test),callbacks=[monitor,checkpointer],verbose=2,epochs=100)

model.load_weights('/content/drive/MyDrive/Colab Notebooks/CSC219-MachineLearning/labs/data/best_weights.hdf5') # load weights from best model
# Out:
# Epoch 1/100
# 4/4 - 1s - loss: 1.3241 - val_loss: 1.2932 - 992ms/epoch - 248ms/step
# Epoch 2/100
# 4/4 - 0s - loss: 1.2767 - val_loss: 1.2607 - 76ms/epoch - 19ms/step
# Epoch 3/100
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4/4 - 0s - loss: 1.2318 - val_loss: 1.2289 - 94ms/epoch - 23ms/step
# Epoch 4/100
# 4/4 - 0s - loss: 1.1981 - val_loss: 1.1975 - 94ms/epoch - 24ms/step
# Epoch 5/100
# 4/4 - 0s - loss: 1.1633 - val_loss: 1.1639 - 81ms/epoch - 20ms/step
# Epoch 6/100
# 4/4 - 0s - loss: 1.1314 - val_loss: 1.1317 - 96ms/epoch - 24ms/step
# Epoch 7/100
# 4/4 - 0s - loss: 1.1042 - val_loss: 1.1036 - 73ms/epoch - 18ms/step
# Epoch 8/100
# 4/4 - 0s - loss: 1.0793 - val_loss: 1.0775 - 56ms/epoch - 14ms/step
# Epoch 9/100
# 4/4 - 0s - loss: 1.0551 - val_loss: 1.0546 - 48ms/epoch - 12ms/step
# Epoch 10/100
# 4/4 - 0s - loss: 1.0354 - val_loss: 1.0327 - 48ms/epoch - 12ms/step
# Epoch 11/100
# 4/4 - 0s - loss: 1.0150 - val_loss: 1.0125 - 65ms/epoch - 16ms/step
# Epoch 12/100
# 4/4 - 0s - loss: 0.9955 - val_loss: 0.9917 - 163ms/epoch - 41ms/step
# Epoch 13/100
# 4/4 - 0s - loss: 0.9765 - val_loss: 0.9713 - 68ms/epoch - 17ms/step
# Epoch 14/100
# 4/4 - 0s - loss: 0.9583 - val_loss: 0.9518 - 87ms/epoch - 22ms/step
# Epoch 15/100
# 4/4 - 0s - loss: 0.9394 - val_loss: 0.9280 - 72ms/epoch - 18ms/step
# Epoch 16/100
# 4/4 - 0s - loss: 0.9191 - val_loss: 0.9039 - 63ms/epoch - 16ms/step
# Epoch 17/100
# 4/4 - 0s - loss: 0.8982 - val_loss: 0.8796 - 126ms/epoch - 32ms/step
# Epoch 18/100
# 4/4 - 0s - loss: 0.8780 - val_loss: 0.8533 - 109ms/epoch - 27ms/step
# Epoch 19/100
# 4/4 - 0s - loss: 0.8568 - val_loss: 0.8290 - 103ms/epoch - 26ms/step
# Epoch 20/100
# 4/4 - 0s - loss: 0.8378 - val_loss: 0.8044 - 84ms/epoch - 21ms/step
# Epoch 21/100
# 4/4 - 0s - loss: 0.8178 - val_loss: 0.7815 - 77ms/epoch - 19ms/step
# Epoch 22/100
# 4/4 - 0s - loss: 0.7975 - val_loss: 0.7589 - 73ms/epoch - 18ms/step
# Epoch 23/100
# 4/4 - 0s - loss: 0.7786 - val_loss: 0.7368 - 66ms/epoch - 17ms/step
# Epoch 24/100
# 4/4 - 0s - loss: 0.7595 - val_loss: 0.7159 - 94ms/epoch - 23ms/step
# Epoch 25/100
# 4/4 - 0s - loss: 0.7407 - val_loss: 0.6952 - 92ms/epoch - 23ms/step
# Epoch 26/100
# 4/4 - 0s - loss: 0.7223 - val_loss: 0.6754 - 82ms/epoch - 20ms/step
# Epoch 27/100
# 4/4 - 0s - loss: 0.7048 - val_loss: 0.6568 - 97ms/epoch - 24ms/step
# Epoch 28/100
# 4/4 - 0s - loss: 0.6881 - val_loss: 0.6409 - 76ms/epoch - 19ms/step
# Epoch 29/100
# 4/4 - 0s - loss: 0.6722 - val_loss: 0.6230 - 47ms/epoch - 12ms/step
# Epoch 30/100
# 4/4 - 0s - loss: 0.6567 - val_loss: 0.6060 - 45ms/epoch - 11ms/step
# Epoch 31/100
# 4/4 - 0s - loss: 0.6418 - val_loss: 0.5904 - 49ms/epoch - 12ms/step
# Epoch 32/100
# 4/4 - 0s - loss: 0.6276 - val_loss: 0.5742 - 46ms/epoch - 12ms/step
# Epoch 33/100
# 4/4 - 0s - loss: 0.6141 - val_loss: 0.5590 - 53ms/epoch - 13ms/step
# Epoch 34/100
# 4/4 - 0s - loss: 0.6025 - val_loss: 0.5452 - 56ms/epoch - 14ms/step
# Epoch 35/100
# 4/4 - 0s - loss: 0.5905 - val_loss: 0.5331 - 51ms/epoch - 13ms/step
# Epoch 36/100
# 4/4 - 0s - loss: 0.5791 - val_loss: 0.5221 - 54ms/epoch - 13ms/step
# Epoch 37/100
# 4/4 - 0s - loss: 0.5687 - val_loss: 0.5117 - 52ms/epoch - 13ms/step
# Epoch 38/100
# 4/4 - 0s - loss: 0.5581 - val_loss: 0.5020 - 47ms/epoch - 12ms/step
# Epoch 39/100
# 4/4 - 0s - loss: 0.5486 - val_loss: 0.4922 - 52ms/epoch - 13ms/step
# Epoch 40/100
# 4/4 - 0s - loss: 0.5395 - val_loss: 0.4829 - 46ms/epoch - 11ms/step
# Epoch 41/100
# 4/4 - 0s - loss: 0.5315 - val_loss: 0.4744 - 64ms/epoch - 16ms/step
# Epoch 42/100
# 4/4 - 0s - loss: 0.5227 - val_loss: 0.4663 - 48ms/epoch - 12ms/step
# Epoch 43/100
# 4/4 - 0s - loss: 0.5150 - val_loss: 0.4589 - 53ms/epoch - 13ms/step
# Epoch 44/100
# 4/4 - 0s - loss: 0.5073 - val_loss: 0.4515 - 45ms/epoch - 11ms/step
# Epoch 45/100
# 4/4 - 0s - loss: 0.5008 - val_loss: 0.4441 - 48ms/epoch - 12ms/step
# Epoch 46/100
# 4/4 - 0s - loss: 0.4947 - val_loss: 0.4374 - 44ms/epoch - 11ms/step
# Epoch 47/100
# 4/4 - 0s - loss: 0.4876 - val_loss: 0.4311 - 54ms/epoch - 14ms/step
# Epoch 48/100
# 4/4 - 0s - loss: 0.4816 - val_loss: 0.4251 - 52ms/epoch - 13ms/step
# Epoch 49/100
# 4/4 - 0s - loss: 0.4757 - val_loss: 0.4192 - 53ms/epoch - 13ms/step
# Epoch 50/100
# 4/4 - 0s - loss: 0.4703 - val_loss: 0.4137 - 57ms/epoch - 14ms/step
# Epoch 51/100
# 4/4 - 0s - loss: 0.4642 - val_loss: 0.4088 - 53ms/epoch - 13ms/step
# Epoch 52/100
# 4/4 - 0s - loss: 0.4596 - val_loss: 0.4049 - 50ms/epoch - 12ms/step
# Epoch 53/100
# 4/4 - 0s - loss: 0.4536 - val_loss: 0.4004 - 54ms/epoch - 13ms/step
# Epoch 54/100
# 4/4 - 0s - loss: 0.4485 - val_loss: 0.3964 - 66ms/epoch - 16ms/step
# Epoch 55/100
# 4/4 - 0s - loss: 0.4444 - val_loss: 0.3917 - 52ms/epoch - 13ms/step
# Epoch 56/100
# 4/4 - 0s - loss: 0.4394 - val_loss: 0.3877 - 52ms/epoch - 13ms/step
# Epoch 57/100
# 4/4 - 0s - loss: 0.4349 - val_loss: 0.3826 - 52ms/epoch - 13ms/step
# Epoch 58/100
# 4/4 - 0s - loss: 0.4293 - val_loss: 0.3769 - 50ms/epoch - 12ms/step
# Epoch 59/100
# 4/4 - 0s - loss: 0.4240 - val_loss: 0.3712 - 50ms/epoch - 13ms/step
# Epoch 60/100
# 4/4 - 0s - loss: 0.4199 - val_loss: 0.3664 - 49ms/epoch - 12ms/step
# Epoch 61/100
# 4/4 - 0s - loss: 0.4167 - val_loss: 0.3621 - 67ms/epoch - 17ms/step
# Epoch 62/100
# 4/4 - 0s - loss: 0.4120 - val_loss: 0.3577 - 49ms/epoch - 12ms/step
# Epoch 63/100
# 4/4 - 0s - loss: 0.4071 - val_loss: 0.3538 - 49ms/epoch - 12ms/step
# Epoch 64/100
# 4/4 - 0s - loss: 0.4022 - val_loss: 0.3509 - 51ms/epoch - 13ms/step
# Epoch 65/100
# 4/4 - 0s - loss: 0.3974 - val_loss: 0.3467 - 53ms/epoch - 13ms/step
# Epoch 66/100
# 4/4 - 0s - loss: 0.3928 - val_loss: 0.3428 - 52ms/epoch - 13ms/step
# Epoch 67/100
# 4/4 - 0s - loss: 0.3887 - val_loss: 0.3387 - 47ms/epoch - 12ms/step
# Epoch 68/100
# 4/4 - 0s - loss: 0.3843 - val_loss: 0.3340 - 51ms/epoch - 13ms/step
# Epoch 69/100
# 4/4 - 0s - loss: 0.3817 - val_loss: 0.3297 - 52ms/epoch - 13ms/step
# Epoch 70/100
# 4/4 - 0s - loss: 0.3764 - val_loss: 0.3260 - 49ms/epoch - 12ms/step
# Epoch 71/100
# 4/4 - 0s - loss: 0.3713 - val_loss: 0.3222 - 52ms/epoch - 13ms/step
# Epoch 72/100
# 4/4 - 0s - loss: 0.3669 - val_loss: 0.3192 - 56ms/epoch - 14ms/step
# Epoch 73/100
# 4/4 - 0s - loss: 0.3621 - val_loss: 0.3160 - 50ms/epoch - 12ms/step
# Epoch 74/100
# 4/4 - 0s - loss: 0.3581 - val_loss: 0.3136 - 54ms/epoch - 14ms/step
# Epoch 75/100
# 4/4 - 0s - loss: 0.3548 - val_loss: 0.3123 - 57ms/epoch - 14ms/step
# Epoch 76/100
# 4/4 - 0s - loss: 0.3510 - val_loss: 0.3060 - 46ms/epoch - 12ms/step
# Epoch 77/100
# 4/4 - 0s - loss: 0.3454 - val_loss: 0.3004 - 47ms/epoch - 12ms/step
# Epoch 78/100
# 4/4 - 0s - loss: 0.3402 - val_loss: 0.2961 - 53ms/epoch - 13ms/step
# Epoch 79/100
# 4/4 - 0s - loss: 0.3369 - val_loss: 0.2915 - 52ms/epoch - 13ms/step
# Epoch 80/100
# 4/4 - 0s - loss: 0.3318 - val_loss: 0.2877 - 59ms/epoch - 15ms/step
# Epoch 81/100
# 4/4 - 0s - loss: 0.3293 - val_loss: 0.2856 - 65ms/epoch - 16ms/step
# Epoch 82/100
# 4/4 - 0s - loss: 0.3233 - val_loss: 0.2817 - 55ms/epoch - 14ms/step
# Epoch 83/100
# 4/4 - 0s - loss: 0.3188 - val_loss: 0.2772 - 54ms/epoch - 13ms/step
# Epoch 84/100
# 4/4 - 0s - loss: 0.3162 - val_loss: 0.2728 - 53ms/epoch - 13ms/step
# Epoch 85/100
# 4/4 - 0s - loss: 0.3107 - val_loss: 0.2695 - 48ms/epoch - 12ms/step
# Epoch 86/100
# 4/4 - 0s - loss: 0.3064 - val_loss: 0.2663 - 53ms/epoch - 13ms/step
# Epoch 87/100
# 4/4 - 0s - loss: 0.3025 - val_loss: 0.2639 - 56ms/epoch - 14ms/step
# Epoch 88/100
# 4/4 - 0s - loss: 0.2982 - val_loss: 0.2598 - 52ms/epoch - 13ms/step
# Epoch 89/100
# 4/4 - 0s - loss: 0.2936 - val_loss: 0.2555 - 54ms/epoch - 13ms/step
# Epoch 90/100
# 4/4 - 0s - loss: 0.2920 - val_loss: 0.2517 - 49ms/epoch - 12ms/step
# Epoch 91/100
# 4/4 - 0s - loss: 0.2867 - val_loss: 0.2490 - 48ms/epoch - 12ms/step
# Epoch 92/100
# 4/4 - 0s - loss: 0.2820 - val_loss: 0.2478 - 52ms/epoch - 13ms/step
# Epoch 93/100
# 4/4 - 0s - loss: 0.2807 - val_loss: 0.2462 - 48ms/epoch - 12ms/step
# Epoch 94/100
# 4/4 - 0s - loss: 0.2777 - val_loss: 0.2387 - 55ms/epoch - 14ms/step
# Epoch 95/100
# 4/4 - 0s - loss: 0.2709 - val_loss: 0.2350 - 51ms/epoch - 13ms/step
# Epoch 96/100
# 4/4 - 0s - loss: 0.2672 - val_loss: 0.2319 - 49ms/epoch - 12ms/step
# Epoch 97/100
# 4/4 - 0s - loss: 0.2638 - val_loss: 0.2297 - 55ms/epoch - 14ms/step
# Epoch 98/100
# 4/4 - 0s - loss: 0.2617 - val_loss: 0.2256 - 73ms/epoch - 18ms/step
# Epoch 99/100
# 4/4 - 0s - loss: 0.2556 - val_loss: 0.2235 - 79ms/epoch - 20ms/step
# Epoch 100/100
# 4/4 - 0s - loss: 0.2554 - val_loss: 0.2228 - 58ms/epoch - 15ms/step

# %%
import numpy as np

from sklearn import svm, datasets
from sklearn.metrics import confusion_matrix, classification_report

pred = model.predict(x_test)
pred = np.argmax(pred,axis=1)
y_true = np.argmax(y_test,axis=1)

# Compute confusion matrix
cm = confusion_matrix(y_true, pred)
print(cm)

print('Ploting confusion matrix')
plt.figure()
plot_confusion_matrix(cm, species)
plt.show()


print(classification_report(y_true, pred))
# Out:
# 2/2 [==============================] - 0s 4ms/step
# [[15  0  0]
#  [ 0 11  0]
#  [ 0  0 12]]
# Ploting confusion matrix
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38

# %% [markdown]
# ## 4.4 Visualizing regression models

# %% [markdown]
# We've already seen regression with the MPG dataset.  Regression uses its own set of visualizations, one of the most common is the lift chart.  The following code generates a lift chart.

# %%
# %matplotlib inline
from matplotlib.pyplot import figure, show
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from sklearn import metrics
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint


path = "/content/drive/MyDrive/Colab Notebooks/CSC219-MachineLearning/labs/data"
preprocess = False

filename_read = os.path.join(path,"auto-mpg.csv")
df = pd.read_csv(filename_read,na_values=['NA','?'])

# create feature vector
missing_median(df, 'horsepower')
encode_text_dummy(df, 'origin')
df.drop('name',1,inplace=True)
if preprocess:
    encode_numeric_zscore(df, 'horsepower')
    encode_numeric_zscore(df, 'weight')
    encode_numeric_zscore(df, 'cylinders')
    encode_numeric_zscore(df, 'displacement')
    encode_numeric_zscore(df, 'acceleration')
    encode_numeric_zscore(df, 'year')

# Encode to a 2D matrix for training
x,y = to_xy(df,'mpg')

# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

model = Sequential()
model.add(Dense(100, input_dim=x.shape[1], activation='relu'))      # try changing 100 to 10
model.add(Dense(10, activation='relu'))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=1, mode='auto')

checkpointer = ModelCheckpoint(filepath="/content/drive/MyDrive/Colab Notebooks/CSC219-MachineLearning/labs/data/best_weights.hdf5", verbose=0, save_best_only=True) # save best model

model.fit(x_train,y_train,validation_data=(x_test,y_test),callbacks=[monitor,checkpointer],verbose=2,epochs=500)

model.load_weights('/content/drive/MyDrive/Colab Notebooks/CSC219-MachineLearning/labs/data/best_weights.hdf5') # load weights from best model

# Predict and measure RMSE
pred = model.predict(x_test)

score = np.sqrt(metrics.mean_squared_error(pred,y_test))
print("Score (RMSE): {}".format(score))

# Plot the chart
chart_regression(pred.flatten(),y_test, sort=True)
# Out:
# Epoch 1/500
# <ipython-input-15-790473433a90>:23: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop('name',1,inplace=True)
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 10/10 - 1s - loss: 10934.7646 - val_loss: 419.9990 - 828ms/epoch - 83ms/step
# Epoch 2/500
# 10/10 - 0s - loss: 1229.0608 - val_loss: 846.4293 - 36ms/epoch - 4ms/step
# Epoch 3/500
# 10/10 - 0s - loss: 334.6419 - val_loss: 297.7924 - 62ms/epoch - 6ms/step
# Epoch 4/500
# 10/10 - 0s - loss: 316.7346 - val_loss: 168.8922 - 59ms/epoch - 6ms/step
# Epoch 5/500
# 10/10 - 0s - loss: 153.7208 - val_loss: 157.5301 - 61ms/epoch - 6ms/step
# Epoch 6/500
# 10/10 - 0s - loss: 146.6777 - val_loss: 116.0624 - 59ms/epoch - 6ms/step
# Epoch 7/500
# 10/10 - 0s - loss: 124.3294 - val_loss: 112.8426 - 84ms/epoch - 8ms/step
# Epoch 8/500
# 10/10 - 0s - loss: 120.4969 - val_loss: 107.0536 - 61ms/epoch - 6ms/step
# Epoch 9/500
# 10/10 - 0s - loss: 115.3280 - val_loss: 108.3723 - 35ms/epoch - 4ms/step
# Epoch 10/500
# 10/10 - 0s - loss: 112.7100 - val_loss: 100.5927 - 73ms/epoch - 7ms/step
# Epoch 11/500
# 10/10 - 0s - loss: 109.4630 - val_loss: 98.5321 - 83ms/epoch - 8ms/step
# Epoch 12/500
# 10/10 - 0s - loss: 107.2622 - val_loss: 95.5895 - 81ms/epoch - 8ms/step
# Epoch 13/500
# 10/10 - 0s - loss: 102.7416 - val_loss: 92.1741 - 85ms/epoch - 8ms/step
# Epoch 14/500
# 10/10 - 0s - loss: 101.1430 - val_loss: 90.1099 - 59ms/epoch - 6ms/step
# Epoch 15/500
# 10/10 - 0s - loss: 97.3144 - val_loss: 86.6666 - 77ms/epoch - 8ms/step
# Epoch 16/500
# 10/10 - 0s - loss: 95.5875 - val_loss: 84.8777 - 75ms/epoch - 8ms/step
# Epoch 17/500
# 10/10 - 0s - loss: 92.7970 - val_loss: 82.2535 - 55ms/epoch - 6ms/step
# Epoch 18/500
# 10/10 - 0s - loss: 89.5982 - val_loss: 78.6033 - 53ms/epoch - 5ms/step
# Epoch 19/500
# 10/10 - 0s - loss: 86.6395 - val_loss: 77.1361 - 56ms/epoch - 6ms/step
# Epoch 20/500
# 10/10 - 0s - loss: 84.5244 - val_loss: 73.4122 - 60ms/epoch - 6ms/step
# Epoch 21/500
# 10/10 - 0s - loss: 81.9775 - val_loss: 70.8480 - 88ms/epoch - 9ms/step
# Epoch 22/500
# 10/10 - 0s - loss: 79.3971 - val_loss: 68.9955 - 64ms/epoch - 6ms/step
# Epoch 23/500
# 10/10 - 0s - loss: 77.9549 - val_loss: 66.1821 - 73ms/epoch - 7ms/step
# Epoch 24/500
# 10/10 - 0s - loss: 74.6945 - val_loss: 63.8320 - 53ms/epoch - 5ms/step
# Epoch 25/500
# 10/10 - 0s - loss: 71.9257 - val_loss: 61.3012 - 60ms/epoch - 6ms/step
# Epoch 26/500
# 10/10 - 0s - loss: 69.7918 - val_loss: 59.0064 - 89ms/epoch - 9ms/step
# Epoch 27/500
# 10/10 - 0s - loss: 67.4882 - val_loss: 56.8111 - 59ms/epoch - 6ms/step
# Epoch 28/500
# 10/10 - 0s - loss: 65.5326 - val_loss: 55.4005 - 83ms/epoch - 8ms/step
# Epoch 29/500
# 10/10 - 0s - loss: 63.3895 - val_loss: 52.7617 - 56ms/epoch - 6ms/step
# Epoch 30/500
# 10/10 - 0s - loss: 61.3784 - val_loss: 50.8173 - 57ms/epoch - 6ms/step
# Epoch 31/500
# 10/10 - 0s - loss: 59.7708 - val_loss: 49.3610 - 76ms/epoch - 8ms/step
# Epoch 32/500
# 10/10 - 0s - loss: 57.5605 - val_loss: 47.3284 - 61ms/epoch - 6ms/step
# Epoch 33/500
# 10/10 - 0s - loss: 56.9221 - val_loss: 47.1026 - 55ms/epoch - 6ms/step
# Epoch 34/500
# 10/10 - 0s - loss: 55.5040 - val_loss: 44.3765 - 62ms/epoch - 6ms/step
# Epoch 35/500
# 10/10 - 0s - loss: 52.8233 - val_loss: 42.5976 - 57ms/epoch - 6ms/step
# Epoch 36/500
# 10/10 - 0s - loss: 51.3369 - val_loss: 40.7710 - 62ms/epoch - 6ms/step
# Epoch 37/500
# 10/10 - 0s - loss: 49.7684 - val_loss: 39.3744 - 59ms/epoch - 6ms/step
# Epoch 38/500
# 10/10 - 0s - loss: 48.5909 - val_loss: 38.1064 - 55ms/epoch - 6ms/step
# Epoch 39/500
# 10/10 - 0s - loss: 46.5546 - val_loss: 36.7866 - 54ms/epoch - 5ms/step
# Epoch 40/500
# 10/10 - 0s - loss: 45.3059 - val_loss: 35.5786 - 71ms/epoch - 7ms/step
# Epoch 41/500
# 10/10 - 0s - loss: 44.0188 - val_loss: 34.4481 - 66ms/epoch - 7ms/step
# Epoch 42/500
# 10/10 - 0s - loss: 42.9287 - val_loss: 33.4889 - 54ms/epoch - 5ms/step
# Epoch 43/500
# 10/10 - 0s - loss: 42.1878 - val_loss: 32.7935 - 77ms/epoch - 8ms/step
# Epoch 44/500
# 10/10 - 0s - loss: 41.0188 - val_loss: 31.8350 - 56ms/epoch - 6ms/step
# Epoch 45/500
# 10/10 - 0s - loss: 39.9299 - val_loss: 30.7735 - 55ms/epoch - 6ms/step
# Epoch 46/500
# 10/10 - 0s - loss: 38.9513 - val_loss: 30.5600 - 54ms/epoch - 5ms/step
# Epoch 47/500
# 10/10 - 0s - loss: 37.8824 - val_loss: 29.2975 - 63ms/epoch - 6ms/step
# Epoch 48/500
# 10/10 - 0s - loss: 37.8128 - val_loss: 28.4103 - 55ms/epoch - 6ms/step
# Epoch 49/500
# 10/10 - 0s - loss: 36.7900 - val_loss: 27.4907 - 59ms/epoch - 6ms/step
# Epoch 50/500
# 10/10 - 0s - loss: 36.6681 - val_loss: 28.8179 - 33ms/epoch - 3ms/step
# Epoch 51/500
# 10/10 - 0s - loss: 37.2407 - val_loss: 33.0508 - 50ms/epoch - 5ms/step
# Epoch 52/500
# 10/10 - 0s - loss: 36.4390 - val_loss: 29.4807 - 40ms/epoch - 4ms/step
# Epoch 53/500
# 10/10 - 0s - loss: 36.6080 - val_loss: 24.9759 - 76ms/epoch - 8ms/step
# Epoch 54/500
# 10/10 - 0s - loss: 33.3393 - val_loss: 24.6748 - 60ms/epoch - 6ms/step
# Epoch 55/500
# 10/10 - 0s - loss: 32.3642 - val_loss: 24.5280 - 53ms/epoch - 5ms/step
# Epoch 56/500
# 10/10 - 0s - loss: 32.5576 - val_loss: 23.7661 - 67ms/epoch - 7ms/step
# Epoch 57/500
# 10/10 - 0s - loss: 31.2207 - val_loss: 23.0927 - 56ms/epoch - 6ms/step
# Epoch 58/500
# 10/10 - 0s - loss: 30.8752 - val_loss: 22.7709 - 62ms/epoch - 6ms/step
# Epoch 59/500
# 10/10 - 0s - loss: 30.7631 - val_loss: 22.4078 - 75ms/epoch - 7ms/step
# Epoch 60/500
# 10/10 - 0s - loss: 30.2593 - val_loss: 23.7794 - 51ms/epoch - 5ms/step
# Epoch 61/500
# 10/10 - 0s - loss: 29.9675 - val_loss: 21.8580 - 56ms/epoch - 6ms/step
# Epoch 62/500
# 10/10 - 0s - loss: 29.6055 - val_loss: 21.4218 - 65ms/epoch - 6ms/step
# Epoch 63/500
# 10/10 - 0s - loss: 29.4585 - val_loss: 23.8240 - 33ms/epoch - 3ms/step
# Epoch 64/500
# 10/10 - 0s - loss: 28.7356 - val_loss: 21.1000 - 77ms/epoch - 8ms/step
# Epoch 65/500
# 10/10 - 0s - loss: 29.1847 - val_loss: 20.4815 - 78ms/epoch - 8ms/step
# Epoch 66/500
# 10/10 - 0s - loss: 27.6793 - val_loss: 20.2460 - 59ms/epoch - 6ms/step
# Epoch 67/500
# 10/10 - 0s - loss: 27.3580 - val_loss: 20.0769 - 57ms/epoch - 6ms/step
# Epoch 68/500
# 10/10 - 0s - loss: 27.1830 - val_loss: 19.7873 - 66ms/epoch - 7ms/step
# Epoch 69/500
# 10/10 - 0s - loss: 26.8057 - val_loss: 19.5459 - 56ms/epoch - 6ms/step
# Epoch 70/500
# 10/10 - 0s - loss: 27.0274 - val_loss: 21.7531 - 35ms/epoch - 3ms/step
# Epoch 71/500
# 10/10 - 0s - loss: 27.0199 - val_loss: 19.1654 - 57ms/epoch - 6ms/step
# Epoch 72/500
# 10/10 - 0s - loss: 26.3533 - val_loss: 19.1259 - 65ms/epoch - 7ms/step
# Epoch 73/500
# 10/10 - 0s - loss: 26.1332 - val_loss: 19.3510 - 33ms/epoch - 3ms/step
# Epoch 74/500
# 10/10 - 0s - loss: 25.6587 - val_loss: 18.8192 - 58ms/epoch - 6ms/step
# Epoch 75/500
# 10/10 - 0s - loss: 25.2704 - val_loss: 19.5507 - 42ms/epoch - 4ms/step
# Epoch 76/500
# 10/10 - 0s - loss: 24.8916 - val_loss: 18.4576 - 58ms/epoch - 6ms/step
# Epoch 77/500
# 10/10 - 0s - loss: 25.4250 - val_loss: 18.1797 - 61ms/epoch - 6ms/step
# Epoch 78/500
# 10/10 - 0s - loss: 25.6279 - val_loss: 20.0552 - 32ms/epoch - 3ms/step
# Epoch 79/500
# 10/10 - 0s - loss: 26.0846 - val_loss: 19.3997 - 49ms/epoch - 5ms/step
# Epoch 80/500
# 10/10 - 0s - loss: 24.6725 - val_loss: 17.6503 - 58ms/epoch - 6ms/step
# Epoch 81/500
# 10/10 - 0s - loss: 24.0202 - val_loss: 17.6170 - 63ms/epoch - 6ms/step
# Epoch 82/500
# 10/10 - 0s - loss: 24.2810 - val_loss: 17.3775 - 51ms/epoch - 5ms/step
# Epoch 83/500
# 10/10 - 0s - loss: 23.7070 - val_loss: 17.2631 - 56ms/epoch - 6ms/step
# Epoch 84/500
# 10/10 - 0s - loss: 23.5676 - val_loss: 18.1848 - 40ms/epoch - 4ms/step
# Epoch 85/500
# 10/10 - 0s - loss: 24.1220 - val_loss: 17.3018 - 34ms/epoch - 3ms/step
# Epoch 86/500
# 10/10 - 0s - loss: 23.3993 - val_loss: 16.9780 - 58ms/epoch - 6ms/step
# Epoch 87/500
# 10/10 - 0s - loss: 23.1619 - val_loss: 16.7620 - 65ms/epoch - 6ms/step
# Epoch 88/500
# 10/10 - 0s - loss: 22.8391 - val_loss: 16.7877 - 50ms/epoch - 5ms/step
# Epoch 89/500
# 10/10 - 0s - loss: 22.8425 - val_loss: 17.0957 - 39ms/epoch - 4ms/step
# Epoch 90/500
# 10/10 - 0s - loss: 23.0827 - val_loss: 17.9495 - 31ms/epoch - 3ms/step
# Epoch 91/500
# 10/10 - 0s - loss: 23.5165 - val_loss: 17.7950 - 30ms/epoch - 3ms/step
# Epoch 92/500
# 10/10 - 0s - loss: 23.2117 - val_loss: 16.1310 - 49ms/epoch - 5ms/step
# Epoch 93/500
# 10/10 - 0s - loss: 22.6860 - val_loss: 16.7156 - 39ms/epoch - 4ms/step
# Epoch 94/500
# 10/10 - 0s - loss: 21.9522 - val_loss: 16.8780 - 49ms/epoch - 5ms/step
# Epoch 95/500
# 10/10 - 0s - loss: 23.4489 - val_loss: 16.4331 - 43ms/epoch - 4ms/step
# Epoch 96/500
# 10/10 - 0s - loss: 22.7017 - val_loss: 15.5289 - 59ms/epoch - 6ms/step
# Epoch 97/500
# 10/10 - 0s - loss: 21.5387 - val_loss: 15.4678 - 75ms/epoch - 7ms/step
# Epoch 98/500
# 10/10 - 0s - loss: 22.0298 - val_loss: 15.7021 - 52ms/epoch - 5ms/step
# Epoch 99/500
# 10/10 - 0s - loss: 22.1256 - val_loss: 15.4994 - 39ms/epoch - 4ms/step
# Epoch 100/500
# 10/10 - 0s - loss: 21.1423 - val_loss: 16.0089 - 33ms/epoch - 3ms/step
# Epoch 101/500
# 10/10 - 0s - loss: 21.1911 - val_loss: 16.0038 - 41ms/epoch - 4ms/step
# Epoch 102/500
# 10/10 - 0s - loss: 21.5688 - val_loss: 15.1729 - 70ms/epoch - 7ms/step
# Epoch 103/500
# 10/10 - 0s - loss: 21.1977 - val_loss: 15.6908 - 33ms/epoch - 3ms/step
# Epoch 104/500
# 10/10 - 0s - loss: 20.5472 - val_loss: 15.1022 - 61ms/epoch - 6ms/step
# Epoch 105/500
# 10/10 - 0s - loss: 21.2783 - val_loss: 15.1436 - 34ms/epoch - 3ms/step
# Epoch 106/500
# 10/10 - 0s - loss: 21.2461 - val_loss: 14.5553 - 61ms/epoch - 6ms/step
# Epoch 107/500
# 10/10 - 0s - loss: 20.1844 - val_loss: 14.5325 - 55ms/epoch - 5ms/step
# Epoch 108/500
# 10/10 - 0s - loss: 20.0056 - val_loss: 14.3081 - 59ms/epoch - 6ms/step
# Epoch 109/500
# 10/10 - 0s - loss: 20.0816 - val_loss: 14.0977 - 59ms/epoch - 6ms/step
# Epoch 110/500
# 10/10 - 0s - loss: 19.8652 - val_loss: 14.5851 - 37ms/epoch - 4ms/step
# Epoch 111/500
# 10/10 - 0s - loss: 19.9830 - val_loss: 14.0285 - 62ms/epoch - 6ms/step
# Epoch 112/500
# 10/10 - 0s - loss: 19.6431 - val_loss: 14.5021 - 34ms/epoch - 3ms/step
# Epoch 113/500
# 10/10 - 0s - loss: 19.4664 - val_loss: 14.6054 - 34ms/epoch - 3ms/step
# Epoch 114/500
# 10/10 - 0s - loss: 20.1902 - val_loss: 13.8944 - 105ms/epoch - 11ms/step
# Epoch 115/500
# 10/10 - 0s - loss: 21.3047 - val_loss: 13.4735 - 64ms/epoch - 6ms/step
# Epoch 116/500
# 10/10 - 0s - loss: 19.5190 - val_loss: 13.3825 - 86ms/epoch - 9ms/step
# Epoch 117/500
# 10/10 - 0s - loss: 18.8378 - val_loss: 13.7064 - 60ms/epoch - 6ms/step
# Epoch 118/500
# 10/10 - 0s - loss: 19.1616 - val_loss: 13.2724 - 87ms/epoch - 9ms/step
# Epoch 119/500
# 10/10 - 0s - loss: 18.5858 - val_loss: 13.0758 - 89ms/epoch - 9ms/step
# Epoch 120/500
# 10/10 - 0s - loss: 18.3085 - val_loss: 16.5492 - 43ms/epoch - 4ms/step
# Epoch 121/500
# 10/10 - 0s - loss: 19.2179 - val_loss: 12.8850 - 88ms/epoch - 9ms/step
# Epoch 122/500
# 10/10 - 0s - loss: 19.0927 - val_loss: 12.7991 - 87ms/epoch - 9ms/step
# Epoch 123/500
# 10/10 - 0s - loss: 18.4813 - val_loss: 13.3354 - 65ms/epoch - 7ms/step
# Epoch 124/500
# 10/10 - 0s - loss: 18.1984 - val_loss: 12.6264 - 67ms/epoch - 7ms/step
# Epoch 125/500
# 10/10 - 0s - loss: 18.9522 - val_loss: 12.5844 - 71ms/epoch - 7ms/step
# Epoch 126/500
# 10/10 - 0s - loss: 18.1134 - val_loss: 12.8406 - 60ms/epoch - 6ms/step
# Epoch 127/500
# 10/10 - 0s - loss: 17.9851 - val_loss: 13.9912 - 64ms/epoch - 6ms/step
# Epoch 128/500
# 10/10 - 0s - loss: 17.9462 - val_loss: 12.2976 - 87ms/epoch - 9ms/step
# Epoch 129/500
# 10/10 - 0s - loss: 17.7665 - val_loss: 12.5012 - 65ms/epoch - 6ms/step
# Epoch 130/500
# 10/10 - 0s - loss: 17.6107 - val_loss: 12.1205 - 84ms/epoch - 8ms/step
# Epoch 131/500
# 10/10 - 0s - loss: 17.3443 - val_loss: 12.0790 - 91ms/epoch - 9ms/step
# Epoch 132/500
# 10/10 - 0s - loss: 17.3590 - val_loss: 11.9921 - 82ms/epoch - 8ms/step
# Epoch 133/500
# 10/10 - 0s - loss: 17.9708 - val_loss: 12.4510 - 41ms/epoch - 4ms/step
# Epoch 134/500
# 10/10 - 0s - loss: 18.2891 - val_loss: 11.9160 - 95ms/epoch - 9ms/step
# Epoch 135/500
# 10/10 - 0s - loss: 17.2601 - val_loss: 11.8183 - 67ms/epoch - 7ms/step
# Epoch 136/500
# 10/10 - 0s - loss: 17.4228 - val_loss: 12.5511 - 42ms/epoch - 4ms/step
# Epoch 137/500
# 10/10 - 0s - loss: 17.0671 - val_loss: 13.3645 - 48ms/epoch - 5ms/step
# Epoch 138/500
# 10/10 - 0s - loss: 17.9879 - val_loss: 13.2108 - 60ms/epoch - 6ms/step
# Epoch 139/500
# 10/10 - 0s - loss: 17.8104 - val_loss: 13.6327 - 58ms/epoch - 6ms/step
# Epoch 140/500
# 10/10 - 0s - loss: 16.9875 - val_loss: 12.5520 - 45ms/epoch - 4ms/step
# Epoch 140: early stopping
# 3/3 [==============================] - 0s 5ms/step
# Score (RMSE): 3.4377729892730713

# %% [markdown]
# The lift chart as shown above was achieved by performing the following actions:
#
# * Sort the data by expected output.  Plot the blue line above.  Blue line is always increasing.
# * For every point on the x-axis plot the predicted value for that same data point.  This is the orange line above.
# * The x-axis is the index of test data after sorting.  The index always starts low and ends high.
#
# Reading a lift chart:
# * The expected and predict lines should be close.  Notice where one is above the other.
# * The above chart is the most accurate on lower MPG.

# %% [markdown]
# #### Regression lift chart without sorting on expected output (y_test)

# %%
chart_regression(pred.flatten(),y_test,sort=False)

# %% [markdown]
# ### References:
#
# * [Google Colab](https://colab.research.google.com/) - Free web based platform that includes Python, Juypter Notebooks, and TensorFlow with free GPU support.  No setup needed.
# * [IBM Cognitive Class Labs](https://www.datascientistworkbench.com) - Free web based platform that includes Python, Juypter Notebooks, and TensorFlow.  No setup needed.
# * [Python Anaconda](https://www.continuum.io/downloads) - Python distribution that includes many data science packages, such as Numpy, Scipy, Scikit-Learn, Pandas, and much more.
# * [TensorFlow](https://www.tensorflow.org/) - Google's mathematics package for deep learning.
# * [Kaggle](https://www.kaggle.com/) - Competitive data science.  Good source of sample data.
# * T81-558: Applications of Deep Neural Networks. Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/)
